# %%
DAY 1 
• numbers	
  Python syntax
•	Rules for variable naming
•	Difference between number types
•	How to print values

# %%
**NUMBERS**
  
1.) Types of Numbers in Python
2.) Basic Arithmetic
3.) Differences between classic division and floor division
4.) Object Assignment in Python

# %%
Types of numbers
Python has various "types" of numbers (numeric literals). We'll mainly focus on integers and floating point numbers.

Integers are just whole numbers, positive or negative. For example: 2 and -2 are examples of integers.

Floating point numbers in Python are notable because they have a decimal point in them, or use an exponential (e) to define the number. For example 2.0 and -2.1 are examples of floating point numbers. 4E2 (4 times 10 to the power of 2) is also an example of a floating point number in Python.

Throughout this course we will be mainly working with integers or simple float number types.

Here is a table of the two main types we will spend most of our time working with some examples:

Examples	Number "Type"
1,2,-5,1000	Integers
1.2,-0.5,2e2,3E2	Floating-point numbers

# %%
BAIC ARITHEMATIC

SUM
SUBSTRACT
MULTIPLY
DEVIDE
FLOOR

# %%
1+1
# Out:
# 2

# %%
2-4
# Out:
# -2

# %%
3*8
# Out:
# 24

# %%
8/7
# Out:
# 1.1428571428571428

# %%
8//7
# Out:
# 1

# %%
POWER
ROOT
ORDER(PRIORITY)VXVCCCCCCCCCCCCC
PARENTHESISVXVCCCCCCCCCCCCC

# %%
4**2
# Out:
# 16

# %%
16**.5
# Out:
# 4.0

# %%
8/4*3+6*2
# Out:
# 18.0

# %%
Variable Assignments
Now that we've seen how to use numbers in Python as a calculator let's see how we can assign names and create variables.

We use a single equals sign to assign labels to variables. Let's see a few examples of how we can do this.

# %%
A = 5
A + A
# Out:
# 10

# %%
A +A
# Out:
# 10

# %%
Write a program that asks:
•	User name
•	Age
•	City
Then prints a full sentence

# %%
name = input("what is your name")
age  = input("waht is your age")
city = input("which city are you from")
v = name + " " + age + " "  + city
V
# Out:
# what is your name KUNDAN
# waht is your age 45
# which city are you from RANCHI
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 city = input("which city are you from")
#       4 v = name + " " + age + " "  + city
# ----> 5 V
#
# NameError: name 'V' is not defined

# %%
v = name + " " + age + " "  + city

# %%
print(v)
# Out:
# KUNDAN 45 RANCHI

# %%
design a calculator for addition , substraction, multiplicaiton , divison

# %%
a = float(input("input first number"))
b = float(input("input second number"))
add = print("addition of two number is ", (a + b)) 
substract =   print(("substraction of two number is ", (a - b)) )
multiplication =   print("multiplication of two number is ", (a * b)) 
division =   print("addition of two number is ",(a / b))
# Out:
# input first number 9
# input second number 9
# addition of two number is  18.0
# ('substraction of two number is ', 0.0)
# multiplication of two number is  81.0
# addition of two number is  1.0
